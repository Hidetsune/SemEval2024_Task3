# %% [markdown]
# <a href="https://colab.research.google.com/github/Hidetsune/SemEval2024_Task3/blob/main/SemEval2024_Task10_train_val_data_concat_Hidetsune_Takahashi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Combining train data with val data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import json

# %%
import re

# %%
df_train = pd.read_csv("/content/drive/MyDrive/SemEval Task10/MaSaC_train_erc.csv") #CHANGE HERE
df_val = pd.read_csv("/content/drive/MyDrive/SemEval Task10/MaSaC_validation_erc.csv") #CHANGE HERE

# %%
df_train_val = pd.concat([df_train, df_val], axis = 0)

# %%
df_train_val
# Out:
#                         episode  \
# 0     roseshantstobeadopted.wmv
# 1     roseshantstobeadopted.wmv
# 2     roseshantstobeadopted.wmv
# 3     roseshantstobeadopted.wmv
# 4     roseshantstobeadopted.wmv
# ...                         ...
# 1349                  prefinale
# 1350                  prefinale
# 1351                  prefinale
# 1352                  prefinale
# 1353                  prefinale
#
#                                              utterances speakers  emotions  \
# 0     kya kya bhar ke rakha hai indravadan ne is gha...     maya   disgust
# 1                          ok, chalo rosesh chalo bahar     indu  contempt
# 2                             momma! hath chhodiye dad!   rosesh     anger
# 3     dekho maya ya na bol raha hai! fir tum hi kaho...     indu   neutral
# 4     indravadan, tum kitne salo se ye joke maar rah...     maya   neutral
# ...                                                 ...      ...       ...
# ...

# %%
df_train_val.set_axis([i for i in range(0, len(df_train_val))], axis = 0, inplace = True)
# Out:
# <ipython-input-7-de3769cdaa0a>:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   df_train_val.set_axis([i for i in range(0, len(df_train_val))], axis = 0, inplace = True)

# %%
df_train_val
# Out:
#                         episode  \
# 0     roseshantstobeadopted.wmv
# 1     roseshantstobeadopted.wmv
# 2     roseshantstobeadopted.wmv
# 3     roseshantstobeadopted.wmv
# 4     roseshantstobeadopted.wmv
# ...                         ...
# 9855                  prefinale
# 9856                  prefinale
# 9857                  prefinale
# 9858                  prefinale
# 9859                  prefinale
#
#                                              utterances speakers  emotions  \
# 0     kya kya bhar ke rakha hai indravadan ne is gha...     maya   disgust
# 1                          ok, chalo rosesh chalo bahar     indu  contempt
# 2                             momma! hath chhodiye dad!   rosesh     anger
# 3     dekho maya ya na bol raha hai! fir tum hi kaho...     indu   neutral
# 4     indravadan, tum kitne salo se ye joke maar rah...     maya   neutral
# ...                                                 ...      ...       ...
# ...

# %%
df_train_val.to_csv("task10_train_val_concat.csv", index = False)
